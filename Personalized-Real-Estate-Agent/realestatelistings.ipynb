# %% [markdown]
# This is a starter notebook for the project, you'll have to import the libraries you'll need, you can find a list of the ones available in this workspace in the requirements.txt file in this workspace.

# %%
from langchain.llms import OpenAI

# %%
# Importing the necessary library for OpenAI API
import openai

# Define your OpenAI API key 
api_key = "YOUR_API_KEY"

# %%
prompt_template = f"""Provide 12 real estate listing for the city of LONDON
focusing on the requested features above. All the features can be imagined or real based on your knowledge.

Highlight key neighborhood and property description. 
Your answer must be in the below given example format.

###
Neighborhood: Green Oaks
Price: $800,000
Bedrooms: 3
Bathrooms: 2
House Size: 2,000 sqft
Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.
Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
###
"""

print(prompt_template)
# Out:
# Provide 12 real estate listing for the city of LONDON
# focusing on the requested features above. All the features can be imagined or real based on your knowledge.
#
# Highlight key neighborhood and property description.
# Your answer must be in the below given example format.
#
# ###
# Neighborhood: Green Oaks
# Price: $800,000
# Bedrooms: 3
# Bathrooms: 2
# House Size: 2,000 sqft
# Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.
# ...

# %%
# Function to call the OpenAI GPT-3.5 API
def generate_real_estate_listings(prompt_template):
    try:
        # Calling the OpenAI API with a system message and our prompt in the user message content
        # Use openai.ChatCompletion.create for openai < 1.0
        # openai.chat.completions.create for openai > 1.0
        response = openai.ChatCompletion.create(
          model="gpt-3.5-turbo",
          messages=[
          {
            "role": "system",
            "content": "You are a real state agent who knows properties listing in London Area very well. You are writing about real estate listing in London area. "
          },
          {
            "role": "user",
            "content": prompt_template
          }
          ],
        temperature=1,
        max_tokens=256*10,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
        )
        # The response is a JSON object containing more information than the generated review. We want to return only the message content
        return response.choices[0].message.content
    except Exception as e:
        return f"An error occurred: {e}"

# Generating the response from the mode
review_summary = generate_real_estate_listings(prompt_template)

    

# Printing the output. 
print("Generated review:")
print(review_summary)
# Out:
# Generated review:
# Neighborhood: Kensington
# Price: $1,200,000
# Bedrooms: 4
# Bathrooms: 2
# House Size: 2,500 sqft
# Description: Immerse yourself in the regal charm of this exquisite 4-bedroom, 2-bathroom home in the prestigious neighborhood of Kensington. With its elegant facade and period features, this property offers a taste of luxury living. The spacious bedrooms and beautifully appointed bathrooms provide a comfortable retreat, while the grand living areas are perfect for entertaining. The fully equipped modern kitchen and picturesque garden complete this stately residence.
# Neighborhood Description: Kensington is renowned for its upscale vibe, with high-end shopping, gourmet restaurants, and cultural attractions like the Victoria and Albert Museum. With Hyde Park just a stone's throw away, residents can enjoy relaxing walks and outdoor activities in the heart of the city.
#
# Neighborhood: Shoreditch
# Price: $900,000
# Bedrooms: 2
# Bathrooms: 2
# ...
